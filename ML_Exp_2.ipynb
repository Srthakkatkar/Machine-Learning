# %%
import pandas as pd
import numpy as np
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('score.csv')
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
df.head(10)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
df.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(df['Hours'],df['Scores'],test_size=0.3,random_state=42)

# %%
model = LinearRegression()
model.fit(x_train.values.reshape(-1,1),y_train.values)
# Out:
# LinearRegression()

# %%
y1_pred = model.predict(x_train.values.reshape(-1, 1))
print("Y Predicted : ",y1_pred)
print(y_train)
# Out:
# Y Predicted :  [39.69425223 17.36000808 33.86792767 46.49163089 89.21801101 85.33379464
#  36.78108995 29.0126572  21.24422446 49.40479317 62.02849639 78.53641598
#  56.20217183 77.56536189 13.47579171 74.65219961 92.13117329]
# 22    35
# 5     20
# 2     27
# 12    41
# 15    95
# 3     75
# 4     30
# 20    30
# 17    24
# 21    54
# 18    67
# 24    86
# 7     60
# 10    85
# 14    17
# 19    69
# 6     88
# Name: Scores, dtype: int64

# %%
y_pred = model.predict(x_test.values.reshape(-1, 1))
print("Y Predicted : ",y_pred)
print(y_test)
# Out:
# Y Predicted :  [83.39168645 27.07054902 27.07054902 69.79692914 60.0863882  29.0126572
#  34.83898177 52.31795545]
# 8     81
# 16    30
# 0     21
# 23    76
# 11    62
# 9     25
# 13    42
# 1     47
# Name: Scores, dtype: int64

# %%
error = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error(Testing Set): {error}")
# Out:
# Mean Squared Error(Testing Set): 23.61945761415174

# %%
plt.scatter(x_test, y_test, color='red', label='Actual Scores')
plt.plot(x_test, y_pred, color='red', label='Predicted Scores')
plt.title('Hours vs Scores')
plt.xlabel('Hours Studied')
plt.ylabel('Scores')
plt.legend()
plt.show()
